# %% [markdown]
# # Mount Google Drive

# %%
from google.colab import drive
from google.colab import files
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Install Requirements

# %%
# %%capture
# !pip install python-docx

# %%
import os
import re
import pandas as pd
import numpy as np

# %%
# Import Local Modules
path_wd = '/content/drive/MyDrive/Github/Content/tools/screenplay'
os.chdir(path_wd)

# %load_ext autoreload
# %reload_ext autoreload

import Screenplay
scp = Screenplay.Screenplay()

# %% [markdown]
# # Upload Screenplay Document

# %%
# Run Cell to choose file
os.chdir('/content')
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cf2c1179-cd88-4652-bab7-64f0470320cb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cf2c1179-cd88-4652-bab7-64f0470320cb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
# create a list of dfsc files
ls_dfsc = []
for fn in uploaded.keys():
  dfsc = scp.read.text('/content/' + fn)
  ls_dfsc.append(dfsc)

# %%
dfsc = ls_dfsc[0].head()

# %%
dfsc['Element_zh'] = None

# %%
idx_t =  dfsc['Element_zh'].dropna().index

BATCH_SIZE = 10
while i < len(idx_t):
  dfsc.loc[idx_t[i:i+BATCH_SIZE], 'Element_zh'] = dfsc.loc[idx_t[istart:iend], 'Element'].apply(
      scp.translate.Baidu, lang_from='en', lang_to='zh')
  i += BATCH_SIZE

# %%
dfsc['Character']

# %%
dfsc['Time'].unique()
# Out:
# array(['DAY', None, 'DUSK', 'NIGHT', 'EVENING', 'DAY AUTUMN',
#        'MID-AFTERNOON', 'DAWN', 'MORNING', 'LATER', 'AFTERNOON',
#        'EARLY MORNING', 'MINUTES LATER - EARLY MORNING', 'LATER - DAY',
#        "SZPILMAN'S POV - DAY", 'LATE AFTERNOON', 'DAY.'], dtype=object)

# %%
dfsc['IE'].unique()
# Out:
# array(['INT', None, 'EXT', 'INT./EXT.'], dtype=object)

# %%
dfsc['Location'].unique()
# Out:
# array(['WARSAW (ARCHIVE)', None, 'STUDIO RADIO STATION WARSAW',
#        'STAIRS AND LOBBY RADIO STATION', 'WARSAW APARTMENT',
#        'RUINED WARSAW STREET', 'WARSAW PHARMACY',
#        'WARSAW STREET AND CAFE PARADISO', 'WARSAW STREET',
#        'SZPILMAN APARTMENT SLISKA STREET', 'STREET LEADING TO GHETTO',
#        'GHETTO APARTMENT AND STREET', 'GHETTO WALL', 'MARKET AREA GHETTO',
#        'CHLODNA STREET', 'GHETTO APARTMENT', 'CAFE NOWACZESNA GHETTO',
#        'GHETTO STREET', 'STREET NEAR WALL', 'COURTYARD AND HOUSE',
#        "JEHUDA ZYSKIND'S ROOM",
#        '/INT BUILDING OPPOSITE AND GHETTO APARTMENT', 'CAFE NOWOCZESNA',
#        'CAFE NOWACZESNA', 'STREETS', 'LABOUR BUREAU BUILDING',
#        'ALLEY AND LABOUR BUREAU LATER', 'CHLODNA STREET BRIDGE',
#        'KITCHEN CAFE NOWOCZESNA', 'OFFICE AND FLOOR SCHULTZ FACTORY',
#        '/INT YARD AND WAREHOUSE', 'WAREHOUSE',
#        'SLEEPING QUARTERS ABOVE WAREHOUSE', 'WAREHOUSE YARD',
# ...
